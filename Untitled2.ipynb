# %% [markdown]
# <a href="https://colab.research.google.com/github/auroraji2906/nlp/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os
os.environ["GITHUB_TOKEN"] = userdata.get("GITHUB_TOKEN")

# %%
# %%bash
# mkdir -p /content/SegExt
# cd /content/SegExt
#
# git init
# git remote add origin "https://auroraji2906:${GITHUB_TOKEN}@github.com/auroraji2906/nlp.git"
# git sparse-checkout init --cone
# git sparse-checkout set SigExt
# git pull origin main
# Out:
# Initialized empty Git repository in /content/SegExt/.git/
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# From https://github.com/auroraji2906/nlp
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# %%bash
# git clone https://github.com/amazon-science/SigExt.git
# cd SigExt
# Out:
# Cloning into 'SigExt'...

# %%
# Librerie principali
# !pip install torch torchvision torchaudio --quiet
# !pip install transformers datasets --quiet
# !pip install pytorch-lightning --quiet
# !pip install jsonlines rake_nltk tqdm numpy pandas scikit-learn --quiet
# !pip install rapidfuzz rouge-score matplotlib seaborn --quiet

# NLTK setup
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 35.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 73.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 65.5 MB/s eta 0:00:00
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# %cd /content/SigExt
# Out:
# /content/SigExt

# %% [markdown]
# #SAMSUM

# %%
# %%bash
# python3 src/prepare_data.py --dataset samsum --output_dir experiments/samsum_dataset/
# Out:
# ...
# 100%|██████████| 500/500 [00:02<00:00, 234.68it/s]

# %%
# !python3 src/train_longformer_extractor_context.py \
  --dataset_dir experiments/samsum_dataset/ \
  --checkpoint_dir experiments/samsum_extractor_model/
# Out:
# Seed set to 42
# config.json: 100% 694/694 [00:00<00:00, 5.78MB/s]
# vocab.json: 899kB [00:00, 58.0MB/s]
# merges.txt: 456kB [00:00, 126MB/s]
# tokenizer.json: 1.36MB [00:00, 141MB/s]
# INFO:absl:Using default tokenizer.
# process data: 100% 1000/1000 [00:20<00:00, 49.68it/s]
# INFO:root:keyword ratio 0.39937984951798733
# INFO:root:Dataset size: 999
# INFO:absl:Using default tokenizer.
# process data: 100% 200/200 [00:03<00:00, 58.24it/s]
# INFO:root:keyword ratio 0.4091989833565631
# INFO:root:Dataset size: 187
# 2025-12-13 16:44:46.231195: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765644286.248209    4866 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python3 src/inference_longformer_extractor.py \
  --dataset_dir experiments/samsum_dataset/ \
  --checkpoint_dir experiments/samsum_extractor_model/ \
  --output_dir experiments/samsum_dataset_with_keyphrase/
# Out:
# INFO:root:Using fexperiments/samsum_extractor_model/lightning_logs/version_0/checkpoints/epoch_04-step_004995-recall20_0.813.ckpt
# 2025-12-13 17:30:41.234295: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765647041.251939   16414 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765647041.256881   16414 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765647041.270208   16414 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !pip install boto3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 49.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.2 MB/s eta 0:00:00
# ...

# %%
# !python3 src/zs_summarization.py \
--kw_strategy sigext_topk \
--kw_model_top_k 15 \
--model_name llama \
--dataset samsum \
--dataset_dir experiments/samsum_dataset_with_keyphrase/ \
--output_dir experiments/samsum_extsig_predictions/
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2025-12-13 17:42:42.152061: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765647762.172108   19585 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765647762.177430   19585 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765647762.190129   19585 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
